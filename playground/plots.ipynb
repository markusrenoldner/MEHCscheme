# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # conservation: periodic domain, Re=$\infty$

# %%
data = [1,2.22767e-12,1.26957e-11,-3.51585e-12,-2.57794e-11,-4.53374,7.74989e-11,
2,2.97597e-12,6.99089e-12,-9.09184e-12,5.69322e-12,3.60707e-11,3.60316e-11,
3,2.06888e-12,3.53873e-12,2.39897e-12,1.12852e-11,-8.36771e-11,-8.11333e-11,
4,2.33869e-12,3.08321e-12,5.71543e-13,-5.86553e-12,1.19194e-11,1.25269e-11,
5,2.26755e-12,6.03075e-12,-3.02913e-12,8.12683e-12,-5.38947e-11,-5.81828e-11,
6,2.86084e-12,4.13475e-12,-4.49241e-12,7.28306e-12,-3.38218e-11,-2.85141e-11,
7,2.19772e-12,4.75998e-12,-5.54845e-12,8.59579e-12,5.06617e-11,5.73444e-11,
8,1.59628e-12,2.41916e-12,-7.4305e-12,-1.17577e-11,1.03284e-10,1.05818e-10,
9,5.81361e-13,5.16558e-12,3.56115e-12,-4.98002e-12,-2.54019e-12,-1.89999e-11,
10,2.16198e-12,4.457e-12,-2.60054e-11,-6.29985e-12,2.44377e-10,2.93515e-10,]

time = data[0::7]
m1 = data[1::7]
m2 = data[2::7]
k1 = data[3::7]
k2 = data[4::7]
h1 = data[5::7]
h2 = data[6::7]

# %%
plt.plot(time,m1,label="u")
plt.plot(time,m2,label="v")
plt.legend()
plt.grid()
plt.ylim(0,0.0000000001)
plt.xlabel("time")
plt.ylabel("div(u),div(v)")
# Out:
# Text(0, 0.5, 'div(u),div(v)')

# %%
plt.plot(time,k1,label="K1")
plt.plot(time,k2,label="K2")
plt.legend()
plt.grid()
plt.ylim(-0.0000000001,0.0000000001)
plt.xlabel("time")
plt.ylabel("K1,K2")
# Out:
# Text(0, 0.5, 'K1,K2')

# %%
plt.plot(time,h1,label="H1")
plt.plot(time,h2,label="H2")
plt.legend()
plt.grid()
plt.ylim(-0.000000001,0.000000001)
plt.xlabel("time")
plt.ylabel("H1,H2")
# Out:
# Text(0, 0.5, 'H1,H2')

# %% [markdown]
# # conservation, periodic domain, Re=100
