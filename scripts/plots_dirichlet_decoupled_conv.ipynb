# %%
import numpy as np
import matplotlib.pyplot as plt 
from numpy import genfromtxt

# %% [markdown]
# ### primal field decoupled, Re=1

# %%
datap=[
    0.000907899,
0.15553
,0.0397187
,0.0104057]
# data = genfromtxt("../out/dirichlet_dual_conv_inviscid.txt", delimiter=' ').flatten()

# %% [markdown]
# ### dual (glaube das ist auch mit gecheatetem forcing term)

# %%
datad=[0.000907899
,0.0509056
,0.029695
,0.0176181]

plt.plot(datad[1:],"o-",label="dual")
plt.plot(datap[1:],"o-",label="primal")
plt.tight_layout()
plt.legend()
plt.grid()
plt.yscale("log")
