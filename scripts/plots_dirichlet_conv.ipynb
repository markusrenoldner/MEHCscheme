# %%
import numpy as np
import matplotlib.pyplot as plt 
from numpy import genfromtxt

# %% [markdown]
# ### coupled system

# %%
data = [
18
,0.398174
,0.00566885
,1.3756
,72
,0.202686
,0.00650791
,0.708999
,288
,0.118843
,0.00174333
,0.430737]

r = data[0::4]

plt.plot(r,data[1::4],"m.-",label="v")
plt.plot(r,data[2::4],"c.-",label="u")
plt.plot(r,data[3::4],"k.-",label="u-v")

plt.legend()
plt.yscale("log")
plt.xscale("log")
plt.ylabel("L2error")
plt.xlabel("DOFs")
plt.tight_layout()
plt.grid()

# %% [markdown]
# ### decoupled dual system and primal system

# %%
data = [19
,0.398125
,98
,0.196843
,604
,0.0984503
,4184
,0.0524394
,31024
,0.0625895
]

data = [19
,0.39812
,98
,0.19665
,604
,0.0981374
,4184
,0.0492101
,31024
,0.0249284
]

# dataprimal = [0.0089248
# ,0.00801372
# ,0.00234826
# ,0.00100687
# ,0.000852883]

dataprimal=[0.00776365
,0.00792085
,0.00219333
,0.000567883]

dataprimal2 =[0.0112656
,0.00819555
,0.00241876
,0.000784366
,0.0003173]

dataprimal3 =[0.00652871
,0.00670613
,0.00191106
,0.000657114]

plt.plot(data[0::2],data[1::2],"m.-" ,label="dual")
plt.plot(data[0::2][:-1],dataprimal3,"c.-",label="primal")
plt.plot(data[0::2],dataprimal2,"b.-",label="primal")
plt.yscale("log")
plt.legend()
plt.xscale("log")
plt.ylabel("L2error")
plt.xlabel("DOFs")
plt.tight_layout()
plt.grid()
