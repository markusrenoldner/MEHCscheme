# %%
import numpy as np
import matplotlib.pyplot as plt 
from numpy import genfromtxt

# %% [markdown]
# ### dirichlet: ess BC on dual space, Re=$\infty$ with "fake forcing"

# %%
# data = genfromtxt("../out/dirichlet_dual_conv_inviscid.txt", delimiter=' ').flatten()

data=[
0.000907899
,0.000907899
,0
,0.0581683
,0.15553
,0.481326
,0.0301939
,0.0397187
,0.127848
,0.0176472
,0.0104057
,0.0859218]

v =        data[0::3]
u =        data[1::3]
uvdiff =   data[2::3]

# %%
plt.plot(uvdiff,"c.-",label="$u-v$")
plt.plot(u,"m.-"     ,label="$u-u_{exact}$")
plt.plot(v,"k.--"    ,label="$v-v_{exact}$")
plt.grid()
plt.legend()
plt.tight_layout()
plt.xlabel("mesh refinement steps")
plt.ylabel("$L_2$-error")
plt.xticks(np.arange(0, 4, step=1))
# plt.xscale("log")
plt.yscale("log")
# plt.savefig("../out/plots/")

# %% [markdown]
# ### conservation, Re=1

# %%
data=[0.011405,
0.00162324,
0.00819438,
0.00282755,
0.00948936,
0.00217011,
0.00891757,
0.00249259,
0.00917155,
0.00232649,
0.0090508,
0.00240986,
0.00911218,
0.00236747,
0.00907788,
0.0023889,
0.00909873,
0.00237801,
0.009085,
0.00238355,
0.00909451,
0.00238072,
0.00908766,
0.00238217,
0.00909269,
0.00238142,
0.00908894,
0.00238182,
0.00909175,
0.0023816,
0.00908964,
0.00238172,
0.00909123,
0.00238165,
0.00909003,
0.00238169,
0.00909093,
0.00238167,
0.00909025,
0.00238168,
0.00909077,
0.00238167,
0.00909038,
0.00238168,
0.00909067,
0.00238168,
0.00909045,
0.00238168,
0.00909062,
0.00238168,
0.00909049,
0.00238168,
0.00909059,
0.00238168,
0.00909051,
0.00238168,
0.00909057,
0.00238168,
0.00909053,
0.00238168,]

K1 = data[0::2]
K2 = data[1::2]
plt.plot(K1)
plt.plot(K2)
plt.tight_layout()

# %% [markdown]
# ### consrevation RE=100

# %%
data=[0.000787072,
0.000651318,
0.000919861,
0.000486635,
0.00100827,
0.000522989,
0.00106763,
0.000515917,
0.0011083,
0.000515642,
0.00113551,
0.000514254,
0.00115367,
0.000513615,
0.0011657,
0.000513124,
0.00117363,
0.000512819,
0.00117885,
0.000512617,
0.00118228,
0.000512484,
0.00118454,
0.000512398,
0.00118601,
0.00051234,
0.00118698,
0.000512303,
0.00118762,
0.000512279,
0.00118803,
0.000512263,
0.00118831,
0.000512252,
0.00118849,
0.000512246,
0.0011886,
0.000512241,
0.00118868,
0.000512238,
0.00118873,
0.000512236,
0.00118876,
0.000512235,
0.00118878,
0.000512234,
0.0011888,
0.000512234,
0.00118881,
0.000512233,
0.00118881,
0.000512233,
0.00118882,
0.000512233,
0.00118882,
0.000512233,
0.00118882,
0.000512233,
0.00118882,
0.000512233,]

K1 = data[0::2]
K2 = data[1::2]
plt.plot(K1)
plt.plot(K2)
plt.tight_layout()
