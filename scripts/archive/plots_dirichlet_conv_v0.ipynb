# %%
import numpy as np
import matplotlib.pyplot as plt 
from numpy import genfromtxt

# %% [markdown]
# ### dirichlet: ess BC on dual space

# %%
data = genfromtxt("../out/dirichlet_dual_conv_inviscid.txt", delimiter=' ').flatten()
v =        data[1::5]
u =        data[2::5]
uvdiff =   data[3::5]
time =     data[4::5]
meshsize = data[0::5]

# %%
plt.plot(meshsize,uvdiff,"c.-",label="u-v")
plt.plot(meshsize,u,"m.-"     ,label="u")
plt.plot(meshsize,v,"k.--"    ,label="v")
plt.grid()
plt.legend()
# plt.xlabel("meshsize in multiples of $h_0$")
plt.ylabel("$L_2$-error")
# plt.xscale("log")
plt.yscale("log")
# plt.savefig("../out/conv_TGV_Re500_timedep.pdf")

# %% [markdown]
# ### dirichlet: ess BC on primal space

# %%
data = genfromtxt("../out/dirichlet_primal_conv_inviscid.txt", delimiter=',').flatten()
v =        data[1::5]
u =        data[2::5]
uvdiff =   data[3::5]
time =     data[4::5]
meshsize = data[0::5]

# %%
plt.plot(meshsize,uvdiff,"c.-",label="u-v")
plt.plot(meshsize,u,"m.-"     ,label="u")
plt.plot(meshsize,v,"k.--"    ,label="v")
plt.grid()
plt.legend()
# plt.xlabel("meshsize in multiples of $h_0$")
plt.ylabel("$L_2$-error")
# plt.xscale("log")
plt.yscale("log")
# plt.savefig("../out/conv_TGV_Re500_timedep.pdf")

# %% [markdown]
# ### dirichlet: ess BC on 3 spaces (H1, hcurl, hdiv)

# %%
data = genfromtxt("../out/dirichlet_dual_conv_inviscid.txt", delimiter=',').flatten()

data = [
0.281356
,0.281356
,0
,159.571
,0.19998
,0.182619
,0.625906
,12.4391
,0.169428
,0.147909
,0.650579
,57.2859
,0.0922509
,0.095386
,0.519954
,3514.78
]

v =        data[0::4]
u =        data[1::4]
uvdiff =   data[2::4]
time =     data[3::4]
meshsize = np.arange(0,4)

# %%
plt.plot(meshsize,uvdiff,"c.-",label="u-v")
plt.plot(meshsize,u,"m.-"     ,label="u")
plt.plot(meshsize,v,"k.--"    ,label="v")
plt.grid()
plt.legend()
# plt.xlabel("meshsize in multiples of $h_0$")
plt.ylabel("$L_2$-error")
# plt.xscale("log")
plt.yscale("log")
# plt.savefig("../out/conv_TGV_Re500_timedep.pdf")
